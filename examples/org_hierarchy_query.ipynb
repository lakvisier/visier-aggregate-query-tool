# %% [markdown]
# # Visier Aggregate Query API Tutorial
#
# This notebook teaches you how to use the Visier Aggregate Query API. You'll learn:
# - How the Visier API works
# - How to structure query payloads
# - Understanding dimensions, metrics, and filters
# - How to modify queries for your needs
# - Best practices and common patterns
#
# We'll use the Organization Hierarchy example to demonstrate these concepts.

# %% [markdown]
# ## Understanding the Visier Aggregate Query API
#
# The Visier Aggregate Query API allows you to retrieve aggregated metrics (like employee count, headcount, turnover) grouped by dimensions (like Organization, Country, Function) over time periods.
#
# ### Key Concepts:
# - **Metric**: What you're measuring (e.g., `employeeCount`, `headcount`)
# - **Axes (Dimensions)**: How to group/break down the data
# - **Filters**: Optional constraints to restrict the data
# - **Time Intervals**: The time period for the query
# - **Options**: How results are formatted
#
# ### API Endpoint:
# ```
# POST /v1/data/query/aggregate
# ```
#
# **Official Documentation**: This repository includes the complete OpenAPI specification (`openapi.json`) and an API reference guide (`API_REFERENCE.md`) based on the official Visier API documentation.
#
# Let's start by setting up our environment.

# %%
import sys
from pathlib import Path
import json
import pandas as pd

# Add parent directory to path to import client
sys.path.insert(0, str(Path().resolve().parent))

from client import (
    load_query_payload_from_json,
    execute_vanilla_aggregate_query,
    convert_vanilla_response_to_dataframe,
    get_api_config
)

print("✓ Imports successful")
print("\nThe client module provides functions to:")
print("  - load_query_payload_from_json() - Load query from JSON file")
print("  - execute_vanilla_aggregate_query() - Execute query against Visier API")
print("  - convert_vanilla_response_to_dataframe() - Convert API response to DataFrame")
# Out:
# ✓ Imports successful
#
# The client module provides functions to:
#   - load_query_payload_from_json() - Load query from JSON file
#   - execute_vanilla_aggregate_query() - Execute query against Visier API
#   - convert_vanilla_response_to_dataframe() - Convert API response to DataFrame

# %% [markdown]
# ## Understanding Query Payload Structure
#
# A Visier aggregate query is defined as a JSON payload. Let's examine the structure of a real query payload.

# %%
# Load the org hierarchy payload
# Handle path resolution - notebook might be run from different directories
current_dir = Path.cwd()
if (current_dir / "query_payload_examples_org_hierarchy.json").exists():
    # Running from examples/ directory
    payload_path = current_dir / "query_payload_examples_org_hierarchy.json"
elif (current_dir / "examples" / "query_payload_examples_org_hierarchy.json").exists():
    # Running from project root
    payload_path = current_dir / "examples" / "query_payload_examples_org_hierarchy.json"
else:
    # Try relative to where we added sys.path
    payload_path = Path("examples/query_payload_examples_org_hierarchy.json")

payload = load_query_payload_from_json(str(payload_path))

print("✓ Payload loaded successfully")
print("\n" + "="*70)
print("PAYLOAD STRUCTURE BREAKDOWN")
print("="*70)

# Show the full payload structure
print("\n1. TOP LEVEL STRUCTURE:")
print("   payload")
print("   └── query")
print("       ├── source (the metric)")
print("       ├── axes (dimensions to group by)")
print("       ├── filters (optional constraints)")
print("       └── timeIntervals (time period)")
print("   └── options (result formatting)")

print("\n2. THE METRIC (what we're measuring):")
metric = payload['query']['source']['metric']
print(f"   query.source.metric = '{metric}'")
print(f"   → This tells Visier to return {metric} data")

print("\n3. THE AXES (how to group the data):")
print(f"   query.axes = [{len(payload['query']['axes'])} dimension(s)]")
for i, axis in enumerate(payload['query']['axes'], 1):
    dim_name = axis['dimensionLevelSelection']['dimension']['name']
    qualifying_path = axis['dimensionLevelSelection']['dimension']['qualifyingPath']
    level_ids = axis['dimensionLevelSelection']['levelIds']
    print(f"\n   Axis {i}: {dim_name}")
    print(f"   ├── dimension.name = '{dim_name}'")
    print(f"   ├── dimension.qualifyingPath = '{qualifying_path}'")
    print(f"   └── levelIds = {level_ids}")
    print(f"   → Groups data by {dim_name} at level(s) {', '.join(level_ids)}")

print("\n4. THE FILTERS (optional constraints):")
if 'filters' in payload['query'] and payload['query']['filters']:
    print(f"   query.filters = [{len(payload['query']['filters'])} filter(s)]")
    for i, filter_item in enumerate(payload['query']['filters'], 1):
        if 'memberSet' in filter_item:
            dim_name = filter_item['memberSet']['dimension']['name']
            values = filter_item['memberSet']['values']['included']
            print(f"\n   Filter {i}: {dim_name}")
            print(f"   └── Restricts to: {[v['path'] for v in values]}")
else:
    print("   query.filters = [] (no filters - returns all data)")

print("\n5. TIME INTERVALS (time period):")
ti = payload['query']['timeIntervals']
print(f"   query.timeIntervals.fromDateTime = '{ti['fromDateTime']}'")
print(f"   query.timeIntervals.intervalPeriodType = '{ti['intervalPeriodType']}'")
print(f"   query.timeIntervals.intervalCount = {ti['intervalCount']}")
print(f"   query.timeIntervals.direction = '{ti['direction']}'")
print(f"   → Returns {ti['intervalCount']} {ti['intervalPeriodType'].lower()}(s) going {ti['direction'].lower()} from {ti['fromDateTime']}")
# Out:
# ✓ Payload loaded successfully
#
# ======================================================================
# PAYLOAD STRUCTURE BREAKDOWN
# ======================================================================
#
# 1. TOP LEVEL STRUCTURE:
#    payload
#    └── query
#        ├── source (the metric)
#        ├── axes (dimensions to group by)
#        ├── filters (optional constraints)
#        └── timeIntervals (time period)
#    └── options (result formatting)
#
# 2. THE METRIC (what we're measuring):
#    query.source.metric = 'employeeCount'
#    → This tells Visier to return employeeCount data
#
# 3. THE AXES (how to group the data):
#    query.axes = [3 dimension(s)]
#
#    Axis 1: Organization_Hierarchy
#    ├── dimension.name = 'Organization_Hierarchy'
#    ├── dimension.qualifyingPath = 'Employee'
#    └── levelIds = ['Level_2']
#    → Groups data by Organization_Hierarchy at level(s) Level_2
#
#    Axis 2: Location
#    ├── dimension.name = 'Location'
#    ├── dimension.qualifyingPath = 'Employee'
#    └── levelIds = ['Location_0']
#    → Groups data by Location at level(s) Location_0
#
#    Axis 3: Country_Cost
#    ├── dimension.name = 'Country_Cost'
#    ├── dimension.qualifyingPath = 'Employee'
#    └── levelIds = ['Country']
#    → Groups data by Country_Cost at level(s) Country
#
# 4. THE FILTERS (optional constraints):
#    query.filters = [1 filter(s)]
#
#    Filter 1: Employment_Type
#    └── Restricts to: [['Full-time shifts']]
#
# 5. TIME INTERVALS (time period):
#    query.timeIntervals.fromDateTime = '2025-11-28'
#    query.timeIntervals.intervalPeriodType = 'YEAR'
#    query.timeIntervals.intervalCount = 5
#    query.timeIntervals.direction = 'BACKWARD'
#    → Returns 5 year(s) going backward from 2025-11-28

# %% [markdown]
# ## Understanding Dimensions and Level IDs
#
# **Critical Concept**: For parent-child hierarchies like `Organization_Hierarchy`, you MUST specify actual level IDs that exist in your tenant.
#
# ### Regular Dimensions vs Parent-Child Hierarchies
#
# **Regular Dimensions** (like `Country_Cost`, `Function`):
# - Can often use the dimension name itself as the level ID
# - Example: `levelIds: ["Country"]` for `Country_Cost`
#
# **Parent-Child Hierarchies** (like `Organization_Hierarchy`):
# - MUST use tenant-specific level IDs
# - Common patterns: `["Level_1"]`, `["Level_2"]`, `["Level_3"]`
# - Or named levels: `["Profit_Center"]`, `["Business_Unit"]`
# - **You cannot use the dimension name itself**
#
# ### How to Discover Level IDs
#
# 1. Use the Dimensions API: `GET /v1/data/model/dimensions/{dimension}/levels`
# 2. Check your tenant's data model documentation
# 3. Try common patterns and see what works
# 4. Contact your Visier administrator
#
# Let's see what level IDs are used in our example:

# %%
# Examine the level IDs used in this query
print("LEVEL IDS IN THIS QUERY:")
print("="*70)

for i, axis in enumerate(payload['query']['axes'], 1):
    dim_name = axis['dimensionLevelSelection']['dimension']['name']
    level_ids = axis['dimensionLevelSelection']['levelIds']
    
    print(f"\n{i}. {dim_name}:")
    print(f"   Level IDs: {level_ids}")
    
    if dim_name == "Organization_Hierarchy":
        print(f"   ⚠️  This is a PARENT-CHILD hierarchy")
        print(f"   → Level IDs are tenant-specific")
        print(f"   → Common options: ['Level_1'], ['Level_2'], ['Level_3']")
        print(f"   → Or named: ['Profit_Center'], ['Business_Unit']")
    else:
        print(f"   ✓ This is a regular dimension")
        print(f"   → Level IDs are usually the dimension name or standard levels")

print("\n" + "="*70)
print("KEY TAKEAWAY:")
print("For Organization_Hierarchy, you MUST discover and use the correct")
print("level IDs for your tenant. The dimension name itself won't work!")
# Out:
# LEVEL IDS IN THIS QUERY:
# ======================================================================
#
# 1. Organization_Hierarchy:
#    Level IDs: ['Level_2']
#    ⚠️  This is a PARENT-CHILD hierarchy
#    → Level IDs are tenant-specific
#    → Common options: ['Level_1'], ['Level_2'], ['Level_3']
#    → Or named: ['Profit_Center'], ['Business_Unit']
#
# 2. Location:
#    Level IDs: ['Location_0']
#    ✓ This is a regular dimension
#    → Level IDs are usually the dimension name or standard levels
#
# 3. Country_Cost:
#    Level IDs: ['Country']
#    ✓ This is a regular dimension
#    → Level IDs are usually the dimension name or standard levels
#
# ======================================================================
# KEY TAKEAWAY:
# For Organization_Hierarchy, you MUST discover and use the correct
# level IDs for your tenant. The dimension name itself won't work!

# %% [markdown]
# ## Executing the Query
#
# Now let's execute the query against the Visier API. The API will:
# 1. Authenticate using your credentials (from `.env` file)
# 2. Validate the query payload
# 3. Execute the query against your tenant's data
# 4. Return the results
#
# **API Request Flow:**
# ```
# Your Code → client.py → Visier API → Response → DataFrame
# ```

# %%
# Check API configuration (credentials)
print("API CONFIGURATION:")
print("="*70)
try:
    config = get_api_config()
    print(f"✓ Host: {config.get('host', 'Not set')}")
    print(f"✓ API Key: {'Set' if config.get('apikey') else 'Not set'}")
    print(f"✓ Vanity: {config.get('vanity', 'Not set')}")
    print(f"✓ Username: {config.get('username', 'Not set')}")
    print("\n→ Credentials are loaded from .env file")
    print("→ If missing, run: python query.py --setup")
except Exception as e:
    print(f"✗ Error loading credentials: {e}")
    print("→ Run: python query.py --setup")

print("\n" + "="*70)
print("EXECUTING QUERY:")
print("="*70)
print("\nThe execute_vanilla_aggregate_query() function:")
print("  1. Builds the API request URL")
print("  2. Adds authentication headers")
print("  3. Sends POST request to /v1/data/query/aggregate")
print("  4. Returns the JSON response")

# Execute the query
print("\n→ Executing query...")
response = execute_vanilla_aggregate_query(payload=payload)

print(f"\n✓ Query executed successfully!")
print(f"\nAPI RESPONSE STRUCTURE:")
print(f"  - cells: {len(response.get('cells', []))} data cells")
print(f"  - axes: {len(response.get('axes', []))} dimension axes")
print(f"  - Each cell contains a value for a unique combination of dimensions")
# Out:
# API CONFIGURATION:
# ======================================================================
# ✓ Host: https://css9xazus3demo7.api.visier.io
# ✓ API Key: Set
# ✓ Vanity: css9xazus3demo7
# ✓ Username: laktest
#
# → Credentials are loaded from .env file
# → If missing, run: python query.py --setup
#
# ======================================================================
# EXECUTING QUERY:
# ======================================================================
#
# The execute_vanilla_aggregate_query() function:
#   1. Builds the API request URL
#   2. Adds authentication headers
#   3. Sends POST request to /v1/data/query/aggregate
#   4. Returns the JSON response
#
# → Executing query...
#
# ✓ Query executed successfully!
#
# API RESPONSE STRUCTURE:
#   - cells: 302 data cells
#   - axes: 5 dimension axes
#   - Each cell contains a value for a unique combination of dimensions

# %% [markdown]
# ## Understanding the API Response
#
# The Visier API returns data in a structured format. Let's examine the response structure:

# %%
# Examine the raw API response structure
print("API RESPONSE STRUCTURE:")
print("="*70)
print("\n1. Response Keys:")
for key in response.keys():
    print(f"   - {key}")

print("\n2. Cells (the actual data):")
if 'cells' in response and response['cells']:
    print(f"   - Total cells: {len(response['cells'])}")
    print(f"   - Each cell represents one data point")
    print(f"   - Example cell structure:")
    example_cell = response['cells'][0]
    print(f"     {json.dumps(example_cell, indent=6)[:200]}...")

print("\n3. Axes (dimension information):")
if 'axes' in response:
    print(f"   - Number of axes: {len(response['axes'])}")
    for i, axis in enumerate(response['axes'], 1):
        print(f"   - Axis {i}: {axis.get('name', 'Unknown')}")

print("\n4. Converting to DataFrame:")
print("   The convert_vanilla_response_to_dataframe() function:")
print("   - Extracts dimension values from each cell")
print("   - Extracts the metric value")
print("   - Creates a pandas DataFrame with columns for each dimension")
print("   - Makes the data easy to work with")
# Out:
# API RESPONSE STRUCTURE:
# ======================================================================
#
# 1. Response Keys:
#    - cells
#    - axes
#
# 2. Cells (the actual data):
#    - Total cells: 302
#    - Each cell represents one data point
#    - Example cell structure:
#      {
#       "value": "34",
#       "support": "34",
#       "coordinates": [
#             0,
#             0,
#             0,
#             0,
#             1
#       ]
# }...
#
# 3. Axes (dimension information):
#    - Number of axes: 5
#    - Axis 1: Unknown
#    - Axis 2: Unknown
#    - Axis 3: Unknown
#    - Axis 4: Unknown
#    - Axis 5: Unknown
#
# 4. Converting to DataFrame:
#    The convert_vanilla_response_to_dataframe() function:
#    - Extracts dimension values from each cell
#    - Extracts the metric value
#    - Creates a pandas DataFrame with columns for each dimension
#    - Makes the data easy to work with

# %%
# Convert to DataFrame
metric_id = payload['query']['source']['metric']
df = convert_vanilla_response_to_dataframe(response, metric_id=metric_id)

print("CONVERTED TO DATAFRAME:")
print("="*70)
print(f"\n✓ Rows: {len(df)}")
print(f"✓ Columns: {len(df.columns)}")
print(f"\nColumn Structure:")
print(f"  - Dimensions: {[c for c in df.columns if c not in ['Measures', 'DateInRange', 'value', 'support']]}")
print(f"  - Measures: {[c for c in df.columns if c == 'Measures']}")
print(f"  - DateInRange: Time period for each row")
print(f"  - value: The metric value (employeeCount)")
print(f"  - support: Support count (number of records contributing to this value)")

print("\n" + "="*70)
print("UNDERSTANDING THE DATA:")
print("="*70)
print("\nEach row represents:")
print("  - A unique combination of dimension values")
print("  - At a specific time period")
print("  - With the metric value for that combination")

print("\nExample rows:")
df.head(10)
# Out:
# CONVERTED TO DATAFRAME:
# ======================================================================
#
# ✓ Rows: 302
# ✓ Columns: 7
#
# Column Structure:
#   - Dimensions: ['Organization_Hierarchy', 'Location', 'Country_Cost']
#   - Measures: ['Measures']
#   - DateInRange: Time period for each row
#   - value: The metric value (employeeCount)
#   - support: Support count (number of records contributing to this value)
#
# ======================================================================
# UNDERSTANDING THE DATA:
# ======================================================================
#
# Each row represents:
#   - A unique combination of dimension values
#   - At a specific time period
#   - With the metric value for that combination
#
# Example rows:
#         Measures                     DateInRange Organization_Hierarchy  \
# 0  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 1  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 2  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 3  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 4  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 5  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 6  employeeCount  2021-12-31T23:59:59.999Z - [0]       Customer Support
# 7  employeeCount  2021-12-31T23:59:59.999Z - [0]             E-Commerce
# 8  employeeCount  2021-12-31T23:59:59.999Z - [0]                Finance
# 9  employeeCount  2021-12-31T23:59:59.999Z - [0]                Finance
#
#         Location    Country_Cost  value  support
# 0           APAC       Australia   34.0       34
# 1           APAC           Japan   16.0       16
# 2           EMEA    South Africa   15.0       15
# 3           EMEA  United Kingdom   34.0       34
# 4  North America          Canada   23.0       23
# 5  North America   United States   85.0       85
# 6  South America          Brazil   13.0       13
# 7  North America   United States  251.0      251
# 8           APAC       Australia   28.0       28
# 9           APAC           Japan    2.0        2

# %% [markdown]
# ## Modifying Queries: Changing the Metric
#
# One of the most common modifications is changing what metric you're querying. Let's see how:

# %%
# Example: How to change the metric
print("CHANGING THE METRIC:")
print("="*70)
print("\nCurrent metric:")
print(f"  payload['query']['source']['metric'] = '{payload['query']['source']['metric']}'")

print("\nTo change the metric, modify this field:")
print("  payload['query']['source']['metric'] = 'headcount'")
print("  payload['query']['source']['metric'] = 'turnover'")
print("  payload['query']['source']['metric'] = 'terminationCount'")

print("\n⚠️  Important:")
print("  - Metric names are tenant-specific")
print("  - Contact your Visier administrator for available metrics")
print("  - Use the Data Model API to discover metrics")
print("  - Common metrics: employeeCount, headcount, turnover, terminationCount")

print("\nExample modification:")
modified_payload = payload.copy()
# Uncomment to try a different metric:
# modified_payload['query']['source']['metric'] = 'headcount'
print("  # modified_payload['query']['source']['metric'] = 'headcount'")
print("  # Then re-execute: response = execute_vanilla_aggregate_query(payload=modified_payload)")
# Out:
# CHANGING THE METRIC:
# ======================================================================
#
# Current metric:
#   payload['query']['source']['metric'] = 'employeeCount'
#
# To change the metric, modify this field:
#   payload['query']['source']['metric'] = 'headcount'
#   payload['query']['source']['metric'] = 'turnover'
#   payload['query']['source']['metric'] = 'terminationCount'
#
# ⚠️  Important:
#   - Metric names are tenant-specific
#   - Contact your Visier administrator for available metrics
#   - Use the Data Model API to discover metrics
#   - Common metrics: employeeCount, headcount, turnover, terminationCount
#
# Example modification:
#   # modified_payload['query']['source']['metric'] = 'headcount'
#   # Then re-execute: response = execute_vanilla_aggregate_query(payload=modified_payload)

# %% [markdown]
# ## Modifying Queries: Adding/Removing Dimensions
#
# You can modify which dimensions (axes) are included in your query.

# %% [markdown]
# ## Modifying Queries: Adding Filters
#
# Filters allow you to restrict the data to specific subsets.

# %% [markdown]
# ## Modifying Queries: Changing Time Periods
#
# Time intervals control what time period you're querying.

# %%
print("UNDERSTANDING TIME INTERVALS:")
print("="*70)

ti = payload['query']['timeIntervals']
print("\nCurrent time interval configuration:")
print(f"  fromDateTime: {ti['fromDateTime']}")
print(f"  intervalPeriodType: {ti['intervalPeriodType']}")
print(f"  intervalCount: {ti['intervalCount']}")
print(f"  direction: {ti['direction']}")

print("\nThis means:")
print(f"  → Start from: {ti['fromDateTime']}")
print(f"  → Go {ti['direction'].lower()}: {ti['intervalCount']} {ti['intervalPeriodType'].lower()}(s)")
print(f"  → Result: {ti['intervalCount']} time periods")

print("\nCommon Patterns:")

print("\n1. Year-end snapshots (2021-2025):")
print("   fromDateTime: '2026-01-01'")
print("   intervalPeriodType: 'YEAR'")
print("   intervalCount: 5")
print("   direction: 'BACKWARD'")
print("   → Returns: 2025, 2024, 2023, 2022, 2021 year-end data")

print("\n2. Point-in-time (single date):")
print("   fromDateTime: '2025-01-01'")
print("   intervalPeriodType: 'DAY'")
print("   intervalCount: 1")
print("   direction: 'BACKWARD'")
print("   → Returns: Data for 2025-01-01 only")

print("\n3. Last 12 months:")
print("   fromDateTime: '2025-12-01'")
print("   intervalPeriodType: 'MONTH'")
print("   intervalCount: 12")
print("   direction: 'BACKWARD'")
print("   → Returns: 12 monthly snapshots")

print("\n⚠️  Important:")
print("  - fromDateTime format: 'YYYY-MM-DD'")
print("  - For year-end snapshots, use start of NEXT year with BACKWARD")
print("  - intervalPeriodType options: YEAR, MONTH, DAY, etc.")
print("  - direction: BACKWARD (into past) or FORWARD (into future)")
# Out:
# UNDERSTANDING TIME INTERVALS:
# ======================================================================
#
# Current time interval configuration:
#   fromDateTime: 2025-11-28
#   intervalPeriodType: YEAR
#   intervalCount: 5
#   direction: BACKWARD
#
# This means:
#   → Start from: 2025-11-28
#   → Go backward: 5 year(s)
#   → Result: 5 time periods
#
# Common Patterns:
#
# 1. Year-end snapshots (2021-2025):
#    fromDateTime: '2026-01-01'
#    intervalPeriodType: 'YEAR'
#    intervalCount: 5
#    direction: 'BACKWARD'
#    → Returns: 2025, 2024, 2023, 2022, 2021 year-end data
#
# 2. Point-in-time (single date):
#    fromDateTime: '2025-01-01'
#    intervalPeriodType: 'DAY'
#    intervalCount: 1
#    direction: 'BACKWARD'
#    → Returns: Data for 2025-01-01 only
#
# 3. Last 12 months:
#    fromDateTime: '2025-12-01'
#    intervalPeriodType: 'MONTH'
#    intervalCount: 12
#    direction: 'BACKWARD'
#    → Returns: 12 monthly snapshots
#
# ⚠️  Important:
#   - fromDateTime format: 'YYYY-MM-DD'
#   - For year-end snapshots, use start of NEXT year with BACKWARD
#   - intervalPeriodType options: YEAR, MONTH, DAY, etc.
#   - direction: BACKWARD (into past) or FORWARD (into future)

# %% [markdown]
# ## Understanding Query Options
#
# Options control how results are formatted and displayed. According to the OpenAPI specification, options are optional and have sensible defaults.

# %%
print("QUERY OPTIONS:")
print("="*70)

options = payload.get('options', {})
print("\nCurrent options:")
print(f"  calendarType: {options.get('calendarType', 'Not set (defaults to TENANT_CALENDAR)')}")
print(f"  zeroVisibility: {options.get('zeroVisibility', 'Not set (defaults to SHOW)')}")
print(f"  nullVisibility: {options.get('nullVisibility', 'Not set (defaults to SHOW)')}")

print("\nKey Options (from OpenAPI spec):")

print("\n1. calendarType (enum):")
print("   - 'TENANT_CALENDAR' (default): Uses your tenant's calendar")
print("   - 'GREGORIAN_CALENDAR': Uses Gregorian calendar")
print("   - Used for all time calculations unless overridden")

print("\n2. zeroVisibility (enum):")
print("   - 'SHOW' (default): Include rows where value is 0")
print("   - 'HIDE': Hide rows with 0 values")
print("   - 'ELIMINATE': Remove rows with 0 values")
print("   - Useful for cleaner results")

print("\n3. nullVisibility (enum):")
print("   - 'SHOW' (default): Include rows where value is null/N/A")
print("   - 'HIDE': Hide rows with null values")
print("   - 'ELIMINATE': Remove rows with null values")

print("\n4. memberDisplayMode (enum):")
print("   - 'DEFAULT' (default): Technical member name paths")
print("   - 'COMPACT': Shortened member names")
print("   - 'DISPLAY': Display names when available")
print("   - 'MDX': MDX format with square brackets")
print("   - 'COMPACT_DISPLAY': Compact display names")

print("\n5. axesOverallValueMode (enum):")
print("   - 'NONE' (default): No overall values")
print("   - 'AGGREGATE': Overall values for selected axes members")
print("   - 'OVERALL': Overall values for all axes members")

print("\n6. internal.alignTimeAxisToPeriodEnd (boolean):")
print("   - true: Aligns timestamps to period end (e.g., 2024-12-31T23:59:59.999Z)")
print("   - false: Uses period start")
print("   - Recommended: true for year-end snapshots")

print("\nSee API_REFERENCE.md for complete list of all available options.")
# Out:
# QUERY OPTIONS:
# ======================================================================
#
# Current options:
#   calendarType: TENANT_CALENDAR
#   zeroVisibility: ELIMINATE
#   nullVisibility: ELIMINATE
#
# Key Options (from OpenAPI spec):
#
# 1. calendarType (enum):
#    - 'TENANT_CALENDAR' (default): Uses your tenant's calendar
#    - 'GREGORIAN_CALENDAR': Uses Gregorian calendar
#    - Used for all time calculations unless overridden
#
# 2. zeroVisibility (enum):
#    - 'SHOW' (default): Include rows where value is 0
#    - 'HIDE': Hide rows with 0 values
#    - 'ELIMINATE': Remove rows with 0 values
#    - Useful for cleaner results
#
# 3. nullVisibility (enum):
#    - 'SHOW' (default): Include rows where value is null/N/A
#    - 'HIDE': Hide rows with null values
#    - 'ELIMINATE': Remove rows with null values
#
# 4. memberDisplayMode (enum):
#    - 'DEFAULT' (default): Technical member name paths
#    - 'COMPACT': Shortened member names
#    - 'DISPLAY': Display names when available
#    - 'MDX': MDX format with square brackets
#    - 'COMPACT_DISPLAY': Compact display names
#
# 5. axesOverallValueMode (enum):
#    - 'NONE' (default): No overall values
#    - 'AGGREGATE': Overall values for selected axes members
#    - 'OVERALL': Overall values for all axes members
#
# 6. internal.alignTimeAxisToPeriodEnd (boolean):
#    - true: Aligns timestamps to period end (e.g., 2024-12-31T23:59:59.999Z)
#    - false: Uses period start
#    - Recommended: true for year-end snapshots
#
# See API_REFERENCE.md for complete list of all available options.

# %%
# Example: Build a query from scratch
print("BUILDING A QUERY FROM SCRATCH:")
print("="*70)
print("\nAccording to the OpenAPI specification, an aggregate query requires:")
print("  - query.source (metric or formula)")
print("  - query.axes (at least one dimension - REQUIRED)")
print("  - query.timeIntervals (REQUIRED)")
print("  - query.filters (optional)")
print("  - options (optional)")

example_query = {
    "query": {
        # 1. Define the metric (REQUIRED)
        "source": {
            "metric": "employeeCount"
        },
        
        # 2. Define dimensions (axes) - REQUIRED for aggregate queries
        "axes": [
            {
                "dimensionLevelSelection": {
                    "dimension": {
                        "name": "Country_Cost",
                        "qualifyingPath": "Employee"
                    },
                    "levelIds": ["Country"]
                }
            }
        ],
        
        # 3. Add filters (OPTIONAL - can be omitted)
        "filters": [
            {
                "memberSet": {
                    "dimension": {
                        "name": "Employment_Type",
                        "qualifyingPath": "Employee"
                    },
                    "values": {
                        "included": [
                            {"path": ["Full-time shifts"]}
                        ]
                    }
                }
            }
        ],
        
        # 4. Define time period (REQUIRED)
        "timeIntervals": {
            "fromDateTime": "2026-01-01",
            "intervalPeriodType": "YEAR",
            "intervalCount": 5,
            "direction": "BACKWARD"
        }
    },
    
    # 5. Set options (OPTIONAL)
    "options": {
        "calendarType": "TENANT_CALENDAR",
        "zeroVisibility": "ELIMINATE",
        "nullVisibility": "ELIMINATE",
        "internal": {
            "alignTimeAxisToPeriodEnd": True
        }
    }
}

print("\nComplete query structure:")
print(json.dumps(example_query, indent=2))

print("\n" + "="*70)
print("REQUIRED vs OPTIONAL (from OpenAPI spec):")
print("="*70)
print("REQUIRED:")
print("  ✓ query.source - Metric or formula")
print("  ✓ query.axes - At least one dimension")
print("  ✓ query.timeIntervals - Time period")
print("\nOPTIONAL:")
print("  - query.filters - Constraints (omit if not needed)")
print("  - query.parameterValues - For parameterized metrics")
print("  - options - Result formatting (has defaults)")
# Out:
# BUILDING A QUERY FROM SCRATCH:
# ======================================================================
#
# According to the OpenAPI specification, an aggregate query requires:
#   - query.source (metric or formula)
#   - query.axes (at least one dimension - REQUIRED)
#   - query.timeIntervals (REQUIRED)
#   - query.filters (optional)
#   - options (optional)
#
# Complete query structure:
# {
#   "query": {
#     "source": {
#       "metric": "employeeCount"
#     },
#     "axes": [
#       {
#         "dimensionLevelSelection": {
#           "dimension": {
#             "name": "Country_Cost",
#             "qualifyingPath": "Employee"
#           },
#           "levelIds": [
#             "Country"
#           ]
#         }
#       }
#     ],
#     "filters": [
#       {
#         "memberSet": {
#           "dimension": {
#             "name": "Employment_Type",
#             "qualifyingPath": "Employee"
#           },
#           "values": {
#             "included": [
#               {
#                 "path": [
#                   "Full-time shifts"
#                 ]
#               }
#             ]
#           }
#         }
#       }
#     ],
#     "timeIntervals": {
#       "fromDateTime": "2026-01-01",
#       "intervalPeriodType": "YEAR",
#       "intervalCount": 5,
#       "direction": "BACKWARD"
#     }
#   },
#   "options": {
#     "calendarType": "TENANT_CALENDAR",
#     "zeroVisibility": "ELIMINATE",
#     "nullVisibility": "ELIMINATE",
#     "internal": {
#       "alignTimeAxisToPeriodEnd": true
#     }
#   }
# }
#
# ======================================================================
# REQUIRED vs OPTIONAL (from OpenAPI spec):
# ======================================================================
# REQUIRED:
#   ✓ query.source - Metric or formula
#   ✓ query.axes - At least one dimension
#   ✓ query.timeIntervals - Time period
#
# OPTIONAL:
#   - query.filters - Constraints (omit if not needed)
#   - query.parameterValues - For parameterized metrics
#   - options - Result formatting (has defaults)

# %% [markdown]
# ## Complete Example: Building a Query from Scratch
#
# Let's see how to build a complete query payload programmatically, following the OpenAPI specification.

# %%
# Save to CSV (optional - for further analysis)
output_path = Path("output/org_hierarchy_analysis.csv")
output_path.parent.mkdir(exist_ok=True)
df.to_csv(output_path, index=False)
print(f"✓ Results saved to: {output_path}")
print("\nNote: You can also use the query.py script to save results:")
print("  python query.py --payload examples/query_payload_examples_org_hierarchy.json --output my_results.csv")
# Out:
# ✓ Results saved to: output/org_hierarchy_analysis.csv
#
# Note: You can also use the query.py script to save results:
#   python query.py --payload examples/query_payload_examples_org_hierarchy.json --output my_results.csv

# %% [markdown]
# ## Customize Your Query
#
# You can modify the payload to change:
# - **Metric**: Change `query.source.metric` (e.g., `"headcount"`, `"turnover"`)
# - **Dimensions**: Add/remove/modify items in `query.axes`
# - **Filters**: Modify `query.filters` to restrict data
# - **Time Period**: Change `query.timeIntervals`
#
# After modifying, re-run the cells above to see the new results.

# %% [markdown]
# ## Summary
#
# You've learned:
# - ✅ How the Visier Aggregate Query API works
# - ✅ Query payload structure (source, axes, filters, timeIntervals, options)
# - ✅ The difference between regular dimensions and parent-child hierarchies
# - ✅ How to modify queries (metrics, dimensions, filters, time periods)
# - ✅ Best practices and common pitfalls
#
# **Remember**: Always validate your payloads with `--validate-only` before executing, and work with your Visier administrator to discover available metrics, dimensions, and level IDs for your tenant.

# %%
# Example: Modify the payload
# Uncomment and modify as needed:

# # Change metric
# payload['query']['source']['metric'] = 'headcount'

# # Add a filter
# payload['query']['filters'] = [{
#     "memberSet": {
#         "dimension": {"name": "Employment_Type", "qualifyingPath": "Employee"},
#         "values": {"included": [{"path": ["Full-time shifts"]}]}
#     }
# }]

# # Change time period
# payload['query']['timeIntervals'] = {
#     "fromDateTime": "2025-01-01",
#     "intervalPeriodType": "YEAR",
#     "intervalCount": 3,
#     "direction": "BACKWARD"
# }

print("Modify the payload above and re-run the query cells to see changes")
# Out:
# Modify the payload above and re-run the query cells to see changes
